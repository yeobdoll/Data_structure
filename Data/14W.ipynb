# %% [markdown]
# # C.인접 행렬과 인접 리스트의 복잡도 비교
# ## 메모리 공간: 인접행렬(N^2), 인접리스트(n+2e)
# ## 시간복잡도
# 간선 유무 -> O(1), O(정점차수)
# 정점차수 -> O(n), O(정점차수)
# 인접정점 -> O(n), O(정점차수)
# 간선수 -> O(n^2), O(n+e)
#
# # D.파이썬의 리스트로 인접행렬 표현(2차원 배열)

# %% [markdown]
# # 그래프인접행렬표현(방향)

# %% [markdown]
# ![%EA%B7%B8%EB%9E%98%ED%94%84%EC%9D%B8%EC%A0%91%ED%96%89%EB%A0%AC%ED%91%9C%ED%98%84%28%EB%B0%A9%ED%96%A5%29.jpg](attachment:%EA%B7%B8%EB%9E%98%ED%94%84%EC%9D%B8%EC%A0%91%ED%96%89%EB%A0%AC%ED%91%9C%ED%98%84%28%EB%B0%A9%ED%96%A5%29.jpg)

# %% [markdown]
# # 그래프인접행렬표현(무방향)

# %% [markdown]
# ![%EA%B7%B8%EB%9E%98%ED%94%84%EC%9D%B8%EC%A0%91%ED%96%89%EB%A0%AC%ED%91%9C%ED%98%84%28%EB%AC%B4%EB%B0%A9%ED%96%A5%29.jpg](attachment:%EA%B7%B8%EB%9E%98%ED%94%84%EC%9D%B8%EC%A0%91%ED%96%89%EB%A0%AC%ED%91%9C%ED%98%84%28%EB%AC%B4%EB%B0%A9%ED%96%A5%29.jpg)

# %% [markdown]
# # 연결 성분이란?
# 최대로 연결된 부분 그래프들을 구함
# DFS 깊이우선탐색 또는 BFS 너비우선탐색을 반복적으로 이용(여기서는 깊이우선탐색 사용)
# 아래 그래프에는 2개의 연결된 부분 그래프, 즉 2개의 연결 성분

# %%
def find_connected_component(graph) :
    visited = set()
    colorList = []
    for vtx in graph :
        if vtx not in visited :
            color = dfs_cc(graph, [], vtx, visited)
            colorList.append( color )
    print("그래프 연결성분 개수 = %d " % len(colorList))
    print(colorList)        
def dfs_cc(graph, color, vertex, visited):
    if vertex not in visited :
        visited.add(vertex)
        color.append(vertex)
        nbr = graph[vertex] - visited
        for v in nbr:
            dfs_cc(graph, color, v, visited)
    return color
mygraph = { "A" : set(["B","C"]),
            "B" : set(["A"]),
            "C" : set(["A"]),
            "D" : set(["E"]),
            "E" : set(["D"]),
          }
print("find")
find_connected_component(mygraph)
mygraph = { "A" : set(["B","C"]),
            "B" : set(["A", "D"]),
            "C" : set(["A", "D", "E"]),
            "D" : set(["B", "C", "F"]),
            "E" : set(["C", "G", "H"]),
            "F" : set(["D"]),
            "G" : set(["E", "H"]),
            "H" : set(["E", "G"])
          }
print("find")
find_connected_component(mygraph)
# Out:
# find
# 그래프 연결성분 개수 = 2
# [['A', 'B', 'C'], ['D', 'E']]
# find
# 그래프 연결성분 개수 = 1
# [['A', 'B', 'D', 'F', 'C', 'E', 'G', 'H']]
